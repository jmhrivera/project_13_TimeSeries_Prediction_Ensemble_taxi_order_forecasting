# %% [markdown]
# # Descripción del proyecto
#
# La compañía Sweet Lift Taxi ha recopilado datos históricos sobre pedidos de taxis en los aeropuertos. Para atraer a más conductores durante las horas pico, necesitamos predecir la cantidad de pedidos de taxis para la próxima hora. Construye un modelo para dicha predicción.
#
# La métrica RECM en el conjunto de prueba no debe ser superior a 48.
#
# ## Instrucciones del proyecto.
#
# 1. Descarga los datos y haz el remuestreo por una hora.
# 2. Analiza los datos
# 3. Entrena diferentes modelos con diferentes hiperparámetros. La muestra de prueba debe ser el 10% del conjunto de datos inicial.4. Prueba los datos usando la muestra de prueba y proporciona una conclusión.
#
# ## Descripción de los datos
#
# Los datos se almacenan en el archivo `taxi.csv`.
# El número de pedidos está en la columna `num_orders`.

# %% [markdown]
# ## Preparación

# %% [markdown]
# #### Definir el tipo de proyecto
#
# De acuerdo a las caracteristicas mencionadas del proycto, nos encontramos ante un objetivo de predicción a través de modelos de regresión.

# %% [markdown]
# #### Importación de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
from pmdarima.arima import auto_arima
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics

# %% [markdown]
# #### Importación de dataframe

# %%
# df = pd.read_csv('/datasets/taxi.csv',parse_dates=   ,index_col=)
df = pd.read_csv('D:/Tripleten/datasets/taxi.csv', index_col='datetime', parse_dates=[0] ) #
df.sort_index(inplace=True)

# %% [markdown]
# #### Visión general del df

# %%
print(df.head(), end='\n\n')
df.info()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# #### Revision de duplicados

# %%
df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Revisión de valores nulos
#
# De acuerdo con df.info() no existen valores nulos

# %% [markdown]
# #### Coherencia de datos
#
# Los datos mantienen una tendencia de crecimiento, por el momento muestran coherencia.

# %%
df.resample('W').sum().head(10)
# Out:
#             num_orders
# datetime
# 2018-03-04        5301
# 2018-03-11        9411
# 2018-03-18        9785
# 2018-03-25        9767
# 2018-04-01        9752
# 2018-04-08        9377
# 2018-04-15       10352
# 2018-04-22       11224
# 2018-04-29       12041
# 2018-05-06       10948

# %% [markdown]
# - [X] Identificar tipo de proyecto
# - [X] Nombre de columna correcta
# - [X] Clasificaciones de tipo de dato correctas
# - [X] Dataframe sin duplicados
# - [X] Excluir valores nulos
# - [X] Verificar la coherencia de los datos

# %% [markdown]
# Conclusiones del proceso de preparación.
#
# El conjunto de datos cargado mantiene una limpieza en sus datos (nombre de columna correctamente nombrados, coherencia de datos, inexistencia de duplicados y valores nulos ). Los datos cargados establecen un periodo desde el periodo 2018-03-01 hasta 2018-08-31.

# %% [markdown]
# ## Análisis

# %%
# df.resample('YE').sum()
df_monthly = df.resample('ME').sum()
df_weekly = df.resample('W').sum()
df_daily = df.resample('D').sum()
df_hourly = df.resample('h').sum()

# %%
# titles = ['Gráfico mensual', 'Gráfico semanal', 'Gráfico diario', 'Gráfico por hora']
# interval = [1,4,24,480]

# databases = [df_monthly,df_weekly,df_daily, df_hourly]
# fig, axis = plt.subplots(4,1, figsize=[10,5])

# for i, database in enumerate(databases):
#     axis[i].plot(database.index, database.values, '--o')
#     axis[i].set_title(titles[i])
#     axis[i].set_xticks(database.index)
#     axis[i].set_xticks(database.index[::interval[i]])

# plt.tight_layout()
# plt.show()

# %%
decomposed = seasonal_decompose(df_hourly, model='additive', period =7)
# decomposed.plot()
# plt.title('Orders Trend')
# plt.show()

# %% [markdown]
# ## Formación

# %% [markdown]
# Definiendo función para crear mas columnas de información

# %%
def make_features(df, max_lag, rolling_mean_size):
    '''Esta función tomará una serie temporal y creara columnas para aumentar su posibilidad de predicción
     en modelos de machine learning, generará columnas de año, mes, día, día de la semana y generará desfaces en los valores definidos 
    por la entrada, también generará una columna con el promedio móvil'''

    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    df['dayofweek'] = df.index.dayofweek

    for lag in range(1, max_lag +1):
        df[f'lag_{lag}'] = df['num_orders'].shift(lag)

    # df['rolling_mean'] = df['num_orders'].rolling(rolling_mean_size).mean()
    df['rolling_mean'] = df['num_orders'].shift().rolling(rolling_mean_size).mean()

make_features(df_hourly,3,3)

df_hourly.dropna(inplace=True)

# %%
y= df_hourly['num_orders']
X= df_hourly.drop(columns='num_orders')

X_train, X_test,y_train, y_test = train_test_split(X,y,shuffle=False, test_size=1/10) #10% del conjuntos de datos inicial

# %% [markdown]
# ## Prueba

# %% [markdown]
# Modelo Linear Regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
test_y_predict = model.predict(X_test)
test_rmse_score = root_mean_squared_error(y_test,test_y_predict)

y_predict = model.predict(X)
rmse_score = root_mean_squared_error(y,y_predict)

print(f'Test Score:{test_rmse_score}')
print(f'DF_Score:{rmse_score}')
# Out:
# Test Score:52.45420941511783
# DF_Score:33.44602050649104

# %%
lenght = len(test_y_predict)
print(f'Los demás ejercicios los  haremos con predicción de longitud {lenght}')
# Out:
# Los demás ejercicios los  haremos con predicción de longitud 442

# %% [markdown]
# Modelo Auto Arima

# %%
df_arima = df_hourly['num_orders']
train, test = train_test_split(df_arima, shuffle=False, test_size=1/10)

# %%
model = auto_arima(train, seasonal=True, m=len(test) )
summary = model.summary()
predict = model.predict(n_periods=len(test))

rmse_score = root_mean_squared_error(test, predict)
print(f'DF_Score:{rmse_score}')

# %% [markdown]
# Modelo Prophet (Meta)

# %%
# df_prophet = pd.DataFrame(data={"ds":df_hourly.index,"y":df_hourly['num_orders']})
# df_prophet = df_prophet.reset_index(drop=True)

# model = Prophet()
# model.fit(df_prophet)

# #Creando mas periodos
# future = model.make_future_dataframe(periods=24, freq='H') 

# # Realizar las predicciones
# forecast = model.predict(future)

# # Definir el número de periodos hacia adelante para la validación cruzada
# horizon = '12 days'

# # Definir el tamaño de cada corte en la validación cruzada
# initial = '5 days'  # Por ejemplo, 120 días de datos iniciales

# # Definir el período de ventana entre cada corte en la validación cruzada
# period = '24 hours'  # Por ejemplo, una ventana de 24 horas entre cada corte

# # Realizar la validación cruzada
# df_cv = cross_validation(model, horizon=horizon, initial=initial, period=period)
# Out:
# 15:11:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:25 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\jm_he\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\prophet\forecaster.py:1854: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(
# Seasonality has period of 7 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/167 [00:00<?, ?it/s]15:11:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:27 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 1/167 [00:00<00:47,  3.51it/s]15:11:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:27 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 2/167 [00:00<00:48,  3.40it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 3/167 [00:00<00:48,  3.37it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 4/167 [00:01<00:48,  3.38it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 5/167 [00:01<00:48,  3.37it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▎         | 6/167 [00:01<00:48,  3.32it/s]15:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:29 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 7/167 [00:02<00:48,  3.29it/s]15:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 8/167 [00:02<00:48,  3.25it/s]15:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 9/167 [00:02<00:48,  3.26it/s]15:11:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:30 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 10/167 [00:03<00:48,  3.22it/s]15:11:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:30 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 11/167 [00:03<00:49,  3.17it/s]15:11:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:30 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 12/167 [00:03<00:49,  3.16it/s]15:11:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:31 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 13/167 [00:03<00:48,  3.19it/s]15:11:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:31 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 14/167 [00:04<00:48,  3.17it/s]15:11:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:31 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 15/167 [00:04<00:48,  3.14it/s]15:11:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:32 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 16/167 [00:04<00:48,  3.14it/s]15:11:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:32 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 17/167 [00:05<00:48,  3.10it/s]15:11:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:32 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 18/167 [00:05<00:48,  3.04it/s]15:11:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:33 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█▏        | 19/167 [00:05<00:49,  3.01it/s]15:11:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:33 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 20/167 [00:06<00:48,  3.01it/s]15:11:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:33 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 21/167 [00:06<00:48,  3.01it/s]15:11:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:34 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 22/167 [00:06<00:48,  3.00it/s]15:11:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:34 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 23/167 [00:07<00:47,  3.02it/s]15:11:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:34 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 24/167 [00:07<00:48,  2.95it/s]15:11:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:35 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 25/167 [00:07<00:47,  3.00it/s]15:11:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:35 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 26/167 [00:08<00:46,  3.02it/s]15:11:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:35 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 27/167 [00:08<00:47,  2.94it/s]15:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:36 - cmdstanpy - INFO - Chain [1] done processing
#  17%|█▋        | 28/167 [00:09<00:47,  2.94it/s]15:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:36 - cmdstanpy - INFO - Chain [1] done processing
#  17%|█▋        | 29/167 [00:09<00:48,  2.82it/s]15:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:36 - cmdstanpy - INFO - Chain [1] done processing
#  18%|█▊        | 30/167 [00:09<00:49,  2.76it/s]15:11:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:37 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▊        | 31/167 [00:10<00:50,  2.67it/s]15:11:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:37 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 32/167 [00:10<00:50,  2.68it/s]15:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:38 - cmdstanpy - INFO - Chain [1] done processing
#  20%|█▉        | 33/167 [00:10<00:51,  2.58it/s]15:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:38 - cmdstanpy - INFO - Chain [1] done processing
#  20%|██        | 34/167 [00:11<00:52,  2.52it/s]15:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:38 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 35/167 [00:11<00:51,  2.55it/s]15:11:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:39 - cmdstanpy - INFO - Chain [1] done processing
#  22%|██▏       | 36/167 [00:12<00:51,  2.53it/s]15:11:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:39 - cmdstanpy - INFO - Chain [1] done processing
#  22%|██▏       | 37/167 [00:12<00:50,  2.56it/s]15:11:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:40 - cmdstanpy - INFO - Chain [1] done processing
#  23%|██▎       | 38/167 [00:12<00:50,  2.57it/s]15:11:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:40 - cmdstanpy - INFO - Chain [1] done processing
#  23%|██▎       | 39/167 [00:13<00:48,  2.66it/s]15:11:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:40 - cmdstanpy - INFO - Chain [1] done processing
#  24%|██▍       | 40/167 [00:13<00:49,  2.59it/s]15:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:41 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▍       | 41/167 [00:14<00:47,  2.63it/s]15:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:41 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 42/167 [00:14<00:46,  2.68it/s]15:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:41 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▌       | 43/167 [00:14<00:46,  2.69it/s]15:11:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:46 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 44/167 [00:19<03:19,  1.62s/it]15:11:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:46 - cmdstanpy - INFO - Chain [1] done processing
#  27%|██▋       | 45/167 [00:19<02:35,  1.27s/it]15:11:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:47 - cmdstanpy - INFO - Chain [1] done processing
#  28%|██▊       | 46/167 [00:20<02:01,  1.00s/it]15:11:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:47 - cmdstanpy - INFO - Chain [1] done processing
#  28%|██▊       | 47/167 [00:20<01:38,  1.22it/s]15:11:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:48 - cmdstanpy - INFO - Chain [1] done processing
#  29%|██▊       | 48/167 [00:20<01:20,  1.48it/s]15:11:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:48 - cmdstanpy - INFO - Chain [1] done processing
#  29%|██▉       | 49/167 [00:21<01:11,  1.66it/s]15:11:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:48 - cmdstanpy - INFO - Chain [1] done processing
#  30%|██▉       | 50/167 [00:21<01:04,  1.80it/s]15:11:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:49 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███       | 51/167 [00:22<01:00,  1.93it/s]15:11:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:49 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███       | 52/167 [00:22<00:58,  1.96it/s]15:11:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:50 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 53/167 [00:23<00:56,  2.02it/s]15:11:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:50 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 54/167 [00:23<00:55,  2.04it/s]15:11:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:51 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 55/167 [00:24<00:53,  2.09it/s]15:11:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:51 - cmdstanpy - INFO - Chain [1] done processing
#  34%|███▎      | 56/167 [00:24<00:53,  2.06it/s]15:11:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:52 - cmdstanpy - INFO - Chain [1] done processing
#  34%|███▍      | 57/167 [00:25<00:52,  2.09it/s]15:11:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:52 - cmdstanpy - INFO - Chain [1] done processing
#  35%|███▍      | 58/167 [00:25<00:52,  2.06it/s]15:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:53 - cmdstanpy - INFO - Chain [1] done processing
#  35%|███▌      | 59/167 [00:25<00:49,  2.16it/s]15:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:53 - cmdstanpy - INFO - Chain [1] done processing
#  36%|███▌      | 60/167 [00:26<00:48,  2.20it/s]15:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:54 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 61/167 [00:26<00:49,  2.16it/s]15:11:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:54 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 62/167 [00:27<00:48,  2.15it/s]15:11:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:54 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 63/167 [00:27<00:46,  2.24it/s]15:11:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:55 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 64/167 [00:28<00:45,  2.27it/s]15:11:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:55 - cmdstanpy - INFO - Chain [1] done processing
#  39%|███▉      | 65/167 [00:28<00:43,  2.32it/s]15:11:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:56 - cmdstanpy - INFO - Chain [1] done processing
#  40%|███▉      | 66/167 [00:29<00:43,  2.30it/s]15:11:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:56 - cmdstanpy - INFO - Chain [1] done processing
#  40%|████      | 67/167 [00:29<00:44,  2.25it/s]15:11:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:57 - cmdstanpy - INFO - Chain [1] done processing
#  41%|████      | 68/167 [00:29<00:43,  2.25it/s]15:11:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:57 - cmdstanpy - INFO - Chain [1] done processing
#  41%|████▏     | 69/167 [00:30<00:43,  2.24it/s]15:11:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:57 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 70/167 [00:30<00:42,  2.27it/s]15:11:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:58 - cmdstanpy - INFO - Chain [1] done processing
#  43%|████▎     | 71/167 [00:31<00:42,  2.24it/s]15:11:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:58 - cmdstanpy - INFO - Chain [1] done processing
#  43%|████▎     | 72/167 [00:31<00:42,  2.26it/s]15:11:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:59 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▎     | 73/167 [00:32<00:42,  2.23it/s]15:11:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:59 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 74/167 [00:32<00:42,  2.19it/s]15:12:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:00 - cmdstanpy - INFO - Chain [1] done processing
#  45%|████▍     | 75/167 [00:33<00:41,  2.21it/s]15:12:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:00 - cmdstanpy - INFO - Chain [1] done processing
#  46%|████▌     | 76/167 [00:33<00:41,  2.18it/s]15:12:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:01 - cmdstanpy - INFO - Chain [1] done processing
#  46%|████▌     | 77/167 [00:34<00:41,  2.16it/s]15:12:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:01 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 78/167 [00:34<00:41,  2.14it/s]15:12:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:02 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 79/167 [00:34<00:40,  2.16it/s]15:12:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:02 - cmdstanpy - INFO - Chain [1] done processing
#  48%|████▊     | 80/167 [00:35<00:41,  2.11it/s]15:12:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:03 - cmdstanpy - INFO - Chain [1] done processing
#  49%|████▊     | 81/167 [00:35<00:40,  2.11it/s]15:12:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:03 - cmdstanpy - INFO - Chain [1] done processing
#  49%|████▉     | 82/167 [00:36<00:40,  2.12it/s]15:12:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:04 - cmdstanpy - INFO - Chain [1] done processing
#  50%|████▉     | 83/167 [00:36<00:39,  2.12it/s]15:12:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:04 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 84/167 [00:37<00:38,  2.13it/s]15:12:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:04 - cmdstanpy - INFO - Chain [1] done processing
#  51%|█████     | 85/167 [00:37<00:39,  2.09it/s]15:12:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:05 - cmdstanpy - INFO - Chain [1] done processing
#  51%|█████▏    | 86/167 [00:38<00:39,  2.04it/s]15:12:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:05 - cmdstanpy - INFO - Chain [1] done processing
#  52%|█████▏    | 87/167 [00:38<00:39,  2.05it/s]15:12:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:06 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 88/167 [00:39<00:39,  2.00it/s]15:12:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:06 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 89/167 [00:39<00:38,  2.01it/s]15:12:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:07 - cmdstanpy - INFO - Chain [1] done processing
#  54%|█████▍    | 90/167 [00:40<00:37,  2.03it/s]15:12:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:08 - cmdstanpy - INFO - Chain [1] done processing
#  54%|█████▍    | 91/167 [00:40<00:38,  1.99it/s]15:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:08 - cmdstanpy - INFO - Chain [1] done processing
#  55%|█████▌    | 92/167 [00:41<00:37,  2.01it/s]15:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:09 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▌    | 93/167 [00:41<00:37,  1.96it/s]15:12:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:09 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 94/167 [00:42<00:36,  1.98it/s]15:12:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:10 - cmdstanpy - INFO - Chain [1] done processing
#  57%|█████▋    | 95/167 [00:42<00:35,  2.02it/s]15:12:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:10 - cmdstanpy - INFO - Chain [1] done processing
#  57%|█████▋    | 96/167 [00:43<00:37,  1.92it/s]15:12:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:11 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 97/167 [00:43<00:36,  1.93it/s]15:12:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:11 - cmdstanpy - INFO - Chain [1] done processing
#  59%|█████▊    | 98/167 [00:44<00:34,  1.98it/s]15:12:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:12 - cmdstanpy - INFO - Chain [1] done processing
#  59%|█████▉    | 99/167 [00:45<00:36,  1.86it/s]15:12:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:12 - cmdstanpy - INFO - Chain [1] done processing
#  60%|█████▉    | 100/167 [00:45<00:35,  1.87it/s]15:12:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:13 - cmdstanpy - INFO - Chain [1] done processing
#  60%|██████    | 101/167 [00:46<00:35,  1.84it/s]15:12:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:13 - cmdstanpy - INFO - Chain [1] done processing
#  61%|██████    | 102/167 [00:46<00:34,  1.87it/s]15:12:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:14 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▏   | 103/167 [00:47<00:33,  1.89it/s]15:12:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:14 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▏   | 104/167 [00:47<00:32,  1.92it/s]15:12:15 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:15 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 105/167 [00:48<00:31,  1.94it/s]15:12:15 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:15 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 106/167 [00:48<00:30,  1.97it/s]15:12:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:16 - cmdstanpy - INFO - Chain [1] done processing
#  64%|██████▍   | 107/167 [00:49<00:30,  1.96it/s]15:12:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:16 - cmdstanpy - INFO - Chain [1] done processing
#  65%|██████▍   | 108/167 [00:49<00:30,  1.95it/s]15:12:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:17 - cmdstanpy - INFO - Chain [1] done processing
#  65%|██████▌   | 109/167 [00:50<00:29,  1.95it/s]15:12:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:17 - cmdstanpy - INFO - Chain [1] done processing
#  66%|██████▌   | 110/167 [00:50<00:29,  1.93it/s]15:12:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:18 - cmdstanpy - INFO - Chain [1] done processing
#  66%|██████▋   | 111/167 [00:51<00:28,  1.96it/s]15:12:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:18 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 112/167 [00:51<00:27,  1.98it/s]15:12:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:19 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 113/167 [00:52<00:27,  1.97it/s]15:12:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:19 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 114/167 [00:52<00:27,  1.92it/s]15:12:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:20 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 115/167 [00:53<00:26,  1.94it/s]15:12:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:20 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 116/167 [00:53<00:26,  1.92it/s]15:12:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:21 - cmdstanpy - INFO - Chain [1] done processing
#  70%|███████   | 117/167 [00:54<00:26,  1.92it/s]15:12:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:22 - cmdstanpy - INFO - Chain [1] done processing
#  71%|███████   | 118/167 [00:54<00:25,  1.91it/s]15:12:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:22 - cmdstanpy - INFO - Chain [1] done processing
#  71%|███████▏  | 119/167 [00:55<00:25,  1.91it/s]15:12:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:23 - cmdstanpy - INFO - Chain [1] done processing
#  72%|███████▏  | 120/167 [00:55<00:24,  1.88it/s]15:12:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:23 - cmdstanpy - INFO - Chain [1] done processing
#  72%|███████▏  | 121/167 [00:56<00:24,  1.84it/s]15:12:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:24 - cmdstanpy - INFO - Chain [1] done processing
#  73%|███████▎  | 122/167 [00:57<00:24,  1.85it/s]15:12:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:24 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 123/167 [00:57<00:23,  1.85it/s]15:12:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:25 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▍  | 124/167 [00:58<00:22,  1.88it/s]15:12:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:25 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▍  | 125/167 [00:58<00:22,  1.86it/s]15:12:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:26 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 126/167 [00:59<00:23,  1.77it/s]15:12:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:26 - cmdstanpy - INFO - Chain [1] done processing
#  76%|███████▌  | 127/167 [00:59<00:22,  1.79it/s]15:12:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:27 - cmdstanpy - INFO - Chain [1] done processing
#  77%|███████▋  | 128/167 [01:00<00:21,  1.82it/s]15:12:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:28 - cmdstanpy - INFO - Chain [1] done processing
#  77%|███████▋  | 129/167 [01:00<00:21,  1.80it/s]15:12:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:28 - cmdstanpy - INFO - Chain [1] done processing
#  78%|███████▊  | 130/167 [01:01<00:20,  1.79it/s]15:12:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:29 - cmdstanpy - INFO - Chain [1] done processing
#  78%|███████▊  | 131/167 [01:02<00:20,  1.72it/s]15:12:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:29 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 132/167 [01:02<00:20,  1.73it/s]15:12:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:30 - cmdstanpy - INFO - Chain [1] done processing
#  80%|███████▉  | 133/167 [01:03<00:19,  1.75it/s]15:12:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:30 - cmdstanpy - INFO - Chain [1] done processing
#  80%|████████  | 134/167 [01:03<00:18,  1.74it/s]15:12:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:31 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████  | 135/167 [01:04<00:18,  1.72it/s]15:12:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:32 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 136/167 [01:04<00:18,  1.70it/s]15:12:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:32 - cmdstanpy - INFO - Chain [1] done processing
#  82%|████████▏ | 137/167 [01:05<00:17,  1.69it/s]15:12:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:33 - cmdstanpy - INFO - Chain [1] done processing
#  83%|████████▎ | 138/167 [01:06<00:17,  1.69it/s]15:12:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:33 - cmdstanpy - INFO - Chain [1] done processing
#  83%|████████▎ | 139/167 [01:06<00:16,  1.70it/s]15:12:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:34 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 140/167 [01:07<00:15,  1.70it/s]15:12:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:35 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 141/167 [01:07<00:15,  1.70it/s]15:12:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:35 - cmdstanpy - INFO - Chain [1] done processing
#  85%|████████▌ | 142/167 [01:08<00:14,  1.70it/s]15:12:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:36 - cmdstanpy - INFO - Chain [1] done processing
#  86%|████████▌ | 143/167 [01:09<00:13,  1.73it/s]15:12:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:36 - cmdstanpy - INFO - Chain [1] done processing
#  86%|████████▌ | 144/167 [01:09<00:13,  1.74it/s]15:12:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:37 - cmdstanpy - INFO - Chain [1] done processing
#  87%|████████▋ | 145/167 [01:10<00:12,  1.72it/s]15:12:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:38 - cmdstanpy - INFO - Chain [1] done processing
#  87%|████████▋ | 146/167 [01:10<00:12,  1.68it/s]15:12:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:38 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 147/167 [01:11<00:12,  1.66it/s]15:12:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:39 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▊ | 148/167 [01:12<00:11,  1.65it/s]15:12:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:39 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 149/167 [01:12<00:10,  1.67it/s]15:12:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:40 - cmdstanpy - INFO - Chain [1] done processing
#  90%|████████▉ | 150/167 [01:13<00:10,  1.68it/s]15:12:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:41 - cmdstanpy - INFO - Chain [1] done processing
#  90%|█████████ | 151/167 [01:13<00:09,  1.68it/s]15:12:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:41 - cmdstanpy - INFO - Chain [1] done processing
#  91%|█████████ | 152/167 [01:14<00:08,  1.67it/s]15:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:42 - cmdstanpy - INFO - Chain [1] done processing
#  92%|█████████▏| 153/167 [01:15<00:08,  1.56it/s]15:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:42 - cmdstanpy - INFO - Chain [1] done processing
#  92%|█████████▏| 154/167 [01:15<00:08,  1.59it/s]15:12:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:43 - cmdstanpy - INFO - Chain [1] done processing
#  93%|█████████▎| 155/167 [01:16<00:07,  1.61it/s]15:12:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:44 - cmdstanpy - INFO - Chain [1] done processing
#  93%|█████████▎| 156/167 [01:17<00:06,  1.63it/s]15:12:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:44 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 157/167 [01:17<00:06,  1.66it/s]15:12:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:45 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 158/167 [01:18<00:05,  1.63it/s]15:12:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:46 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 159/167 [01:18<00:05,  1.56it/s]15:12:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:46 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 160/167 [01:19<00:04,  1.54it/s]15:12:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:47 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 161/167 [01:20<00:03,  1.56it/s]15:12:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:48 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 162/167 [01:20<00:03,  1.48it/s]15:12:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:48 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 163/167 [01:21<00:02,  1.50it/s]15:12:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:49 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 164/167 [01:22<00:01,  1.52it/s]15:12:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:50 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 165/167 [01:22<00:01,  1.51it/s]15:12:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:50 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 166/167 [01:23<00:00,  1.50it/s]15:12:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:51 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 167/167 [01:24<00:00,  1.98it/s]

# %%
# df_prophet = pd.DataFrame(data={"ds":df_hourly.index,"y":df_hourly['num_orders']})
# df_prophet = df_prophet.reset_index(drop=True)

# model = Prophet()
# model.fit(df_prophet)

# #Creando mas periodos
# future = model.make_future_dataframe(periods=24, freq='H') 

# # Realizar las predicciones
# forecast = model.predict(future)

# # Definir el número de periodos hacia adelante para la validación cruzada
# horizon = '12 days'

# # Definir el tamaño de cada corte en la validación cruzada
# initial = '5 days'  # Por ejemplo, 120 días de datos iniciales

# # Definir el período de ventana entre cada corte en la validación cruzada
# period = '24 hours'  # Por ejemplo, una ventana de 24 horas entre cada corte

# # Realizar la validación cruzada
# df_cv = cross_validation(model, horizon=horizon, initial=initial, period=period)
# Out:
# 15:11:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:25 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\jm_he\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\prophet\forecaster.py:1854: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(
# Seasonality has period of 7 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/167 [00:00<?, ?it/s]15:11:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:27 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 1/167 [00:00<00:47,  3.51it/s]15:11:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:27 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 2/167 [00:00<00:48,  3.40it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 3/167 [00:00<00:48,  3.37it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 4/167 [00:01<00:48,  3.38it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 5/167 [00:01<00:48,  3.37it/s]15:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▎         | 6/167 [00:01<00:48,  3.32it/s]15:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:29 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 7/167 [00:02<00:48,  3.29it/s]15:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 8/167 [00:02<00:48,  3.25it/s]15:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 9/167 [00:02<00:48,  3.26it/s]15:11:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:30 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 10/167 [00:03<00:48,  3.22it/s]15:11:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:30 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 11/167 [00:03<00:49,  3.17it/s]15:11:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:30 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 12/167 [00:03<00:49,  3.16it/s]15:11:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:31 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 13/167 [00:03<00:48,  3.19it/s]15:11:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:31 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 14/167 [00:04<00:48,  3.17it/s]15:11:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:31 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 15/167 [00:04<00:48,  3.14it/s]15:11:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:32 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 16/167 [00:04<00:48,  3.14it/s]15:11:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:32 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 17/167 [00:05<00:48,  3.10it/s]15:11:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:32 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 18/167 [00:05<00:48,  3.04it/s]15:11:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:33 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█▏        | 19/167 [00:05<00:49,  3.01it/s]15:11:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:33 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 20/167 [00:06<00:48,  3.01it/s]15:11:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:33 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 21/167 [00:06<00:48,  3.01it/s]15:11:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:34 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 22/167 [00:06<00:48,  3.00it/s]15:11:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:34 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 23/167 [00:07<00:47,  3.02it/s]15:11:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:34 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 24/167 [00:07<00:48,  2.95it/s]15:11:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:35 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 25/167 [00:07<00:47,  3.00it/s]15:11:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:35 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 26/167 [00:08<00:46,  3.02it/s]15:11:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:35 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 27/167 [00:08<00:47,  2.94it/s]15:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:36 - cmdstanpy - INFO - Chain [1] done processing
#  17%|█▋        | 28/167 [00:09<00:47,  2.94it/s]15:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:36 - cmdstanpy - INFO - Chain [1] done processing
#  17%|█▋        | 29/167 [00:09<00:48,  2.82it/s]15:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:36 - cmdstanpy - INFO - Chain [1] done processing
#  18%|█▊        | 30/167 [00:09<00:49,  2.76it/s]15:11:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:37 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▊        | 31/167 [00:10<00:50,  2.67it/s]15:11:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:37 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 32/167 [00:10<00:50,  2.68it/s]15:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:38 - cmdstanpy - INFO - Chain [1] done processing
#  20%|█▉        | 33/167 [00:10<00:51,  2.58it/s]15:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:38 - cmdstanpy - INFO - Chain [1] done processing
#  20%|██        | 34/167 [00:11<00:52,  2.52it/s]15:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:38 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 35/167 [00:11<00:51,  2.55it/s]15:11:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:39 - cmdstanpy - INFO - Chain [1] done processing
#  22%|██▏       | 36/167 [00:12<00:51,  2.53it/s]15:11:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:39 - cmdstanpy - INFO - Chain [1] done processing
#  22%|██▏       | 37/167 [00:12<00:50,  2.56it/s]15:11:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:40 - cmdstanpy - INFO - Chain [1] done processing
#  23%|██▎       | 38/167 [00:12<00:50,  2.57it/s]15:11:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:40 - cmdstanpy - INFO - Chain [1] done processing
#  23%|██▎       | 39/167 [00:13<00:48,  2.66it/s]15:11:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:40 - cmdstanpy - INFO - Chain [1] done processing
#  24%|██▍       | 40/167 [00:13<00:49,  2.59it/s]15:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:41 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▍       | 41/167 [00:14<00:47,  2.63it/s]15:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:41 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 42/167 [00:14<00:46,  2.68it/s]15:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:41 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▌       | 43/167 [00:14<00:46,  2.69it/s]15:11:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:46 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 44/167 [00:19<03:19,  1.62s/it]15:11:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:46 - cmdstanpy - INFO - Chain [1] done processing
#  27%|██▋       | 45/167 [00:19<02:35,  1.27s/it]15:11:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:47 - cmdstanpy - INFO - Chain [1] done processing
#  28%|██▊       | 46/167 [00:20<02:01,  1.00s/it]15:11:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:47 - cmdstanpy - INFO - Chain [1] done processing
#  28%|██▊       | 47/167 [00:20<01:38,  1.22it/s]15:11:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:48 - cmdstanpy - INFO - Chain [1] done processing
#  29%|██▊       | 48/167 [00:20<01:20,  1.48it/s]15:11:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:48 - cmdstanpy - INFO - Chain [1] done processing
#  29%|██▉       | 49/167 [00:21<01:11,  1.66it/s]15:11:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:48 - cmdstanpy - INFO - Chain [1] done processing
#  30%|██▉       | 50/167 [00:21<01:04,  1.80it/s]15:11:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:49 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███       | 51/167 [00:22<01:00,  1.93it/s]15:11:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:49 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███       | 52/167 [00:22<00:58,  1.96it/s]15:11:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:50 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 53/167 [00:23<00:56,  2.02it/s]15:11:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:50 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 54/167 [00:23<00:55,  2.04it/s]15:11:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:51 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 55/167 [00:24<00:53,  2.09it/s]15:11:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:51 - cmdstanpy - INFO - Chain [1] done processing
#  34%|███▎      | 56/167 [00:24<00:53,  2.06it/s]15:11:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:52 - cmdstanpy - INFO - Chain [1] done processing
#  34%|███▍      | 57/167 [00:25<00:52,  2.09it/s]15:11:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:52 - cmdstanpy - INFO - Chain [1] done processing
#  35%|███▍      | 58/167 [00:25<00:52,  2.06it/s]15:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:53 - cmdstanpy - INFO - Chain [1] done processing
#  35%|███▌      | 59/167 [00:25<00:49,  2.16it/s]15:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:53 - cmdstanpy - INFO - Chain [1] done processing
#  36%|███▌      | 60/167 [00:26<00:48,  2.20it/s]15:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:54 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 61/167 [00:26<00:49,  2.16it/s]15:11:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:54 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 62/167 [00:27<00:48,  2.15it/s]15:11:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:54 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 63/167 [00:27<00:46,  2.24it/s]15:11:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:55 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 64/167 [00:28<00:45,  2.27it/s]15:11:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:55 - cmdstanpy - INFO - Chain [1] done processing
#  39%|███▉      | 65/167 [00:28<00:43,  2.32it/s]15:11:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:56 - cmdstanpy - INFO - Chain [1] done processing
#  40%|███▉      | 66/167 [00:29<00:43,  2.30it/s]15:11:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:56 - cmdstanpy - INFO - Chain [1] done processing
#  40%|████      | 67/167 [00:29<00:44,  2.25it/s]15:11:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:57 - cmdstanpy - INFO - Chain [1] done processing
#  41%|████      | 68/167 [00:29<00:43,  2.25it/s]15:11:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:57 - cmdstanpy - INFO - Chain [1] done processing
#  41%|████▏     | 69/167 [00:30<00:43,  2.24it/s]15:11:57 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:57 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 70/167 [00:30<00:42,  2.27it/s]15:11:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:58 - cmdstanpy - INFO - Chain [1] done processing
#  43%|████▎     | 71/167 [00:31<00:42,  2.24it/s]15:11:58 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:58 - cmdstanpy - INFO - Chain [1] done processing
#  43%|████▎     | 72/167 [00:31<00:42,  2.26it/s]15:11:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:59 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▎     | 73/167 [00:32<00:42,  2.23it/s]15:11:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:59 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 74/167 [00:32<00:42,  2.19it/s]15:12:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:00 - cmdstanpy - INFO - Chain [1] done processing
#  45%|████▍     | 75/167 [00:33<00:41,  2.21it/s]15:12:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:00 - cmdstanpy - INFO - Chain [1] done processing
#  46%|████▌     | 76/167 [00:33<00:41,  2.18it/s]15:12:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:01 - cmdstanpy - INFO - Chain [1] done processing
#  46%|████▌     | 77/167 [00:34<00:41,  2.16it/s]15:12:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:01 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 78/167 [00:34<00:41,  2.14it/s]15:12:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:02 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 79/167 [00:34<00:40,  2.16it/s]15:12:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:02 - cmdstanpy - INFO - Chain [1] done processing
#  48%|████▊     | 80/167 [00:35<00:41,  2.11it/s]15:12:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:03 - cmdstanpy - INFO - Chain [1] done processing
#  49%|████▊     | 81/167 [00:35<00:40,  2.11it/s]15:12:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:03 - cmdstanpy - INFO - Chain [1] done processing
#  49%|████▉     | 82/167 [00:36<00:40,  2.12it/s]15:12:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:04 - cmdstanpy - INFO - Chain [1] done processing
#  50%|████▉     | 83/167 [00:36<00:39,  2.12it/s]15:12:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:04 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 84/167 [00:37<00:38,  2.13it/s]15:12:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:04 - cmdstanpy - INFO - Chain [1] done processing
#  51%|█████     | 85/167 [00:37<00:39,  2.09it/s]15:12:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:05 - cmdstanpy - INFO - Chain [1] done processing
#  51%|█████▏    | 86/167 [00:38<00:39,  2.04it/s]15:12:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:05 - cmdstanpy - INFO - Chain [1] done processing
#  52%|█████▏    | 87/167 [00:38<00:39,  2.05it/s]15:12:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:06 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 88/167 [00:39<00:39,  2.00it/s]15:12:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:06 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 89/167 [00:39<00:38,  2.01it/s]15:12:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:07 - cmdstanpy - INFO - Chain [1] done processing
#  54%|█████▍    | 90/167 [00:40<00:37,  2.03it/s]15:12:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:08 - cmdstanpy - INFO - Chain [1] done processing
#  54%|█████▍    | 91/167 [00:40<00:38,  1.99it/s]15:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:08 - cmdstanpy - INFO - Chain [1] done processing
#  55%|█████▌    | 92/167 [00:41<00:37,  2.01it/s]15:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:09 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▌    | 93/167 [00:41<00:37,  1.96it/s]15:12:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:09 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 94/167 [00:42<00:36,  1.98it/s]15:12:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:10 - cmdstanpy - INFO - Chain [1] done processing
#  57%|█████▋    | 95/167 [00:42<00:35,  2.02it/s]15:12:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:10 - cmdstanpy - INFO - Chain [1] done processing
#  57%|█████▋    | 96/167 [00:43<00:37,  1.92it/s]15:12:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:11 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 97/167 [00:43<00:36,  1.93it/s]15:12:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:11 - cmdstanpy - INFO - Chain [1] done processing
#  59%|█████▊    | 98/167 [00:44<00:34,  1.98it/s]15:12:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:12 - cmdstanpy - INFO - Chain [1] done processing
#  59%|█████▉    | 99/167 [00:45<00:36,  1.86it/s]15:12:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:12 - cmdstanpy - INFO - Chain [1] done processing
#  60%|█████▉    | 100/167 [00:45<00:35,  1.87it/s]15:12:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:13 - cmdstanpy - INFO - Chain [1] done processing
#  60%|██████    | 101/167 [00:46<00:35,  1.84it/s]15:12:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:13 - cmdstanpy - INFO - Chain [1] done processing
#  61%|██████    | 102/167 [00:46<00:34,  1.87it/s]15:12:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:14 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▏   | 103/167 [00:47<00:33,  1.89it/s]15:12:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:14 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▏   | 104/167 [00:47<00:32,  1.92it/s]15:12:15 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:15 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 105/167 [00:48<00:31,  1.94it/s]15:12:15 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:15 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 106/167 [00:48<00:30,  1.97it/s]15:12:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:16 - cmdstanpy - INFO - Chain [1] done processing
#  64%|██████▍   | 107/167 [00:49<00:30,  1.96it/s]15:12:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:16 - cmdstanpy - INFO - Chain [1] done processing
#  65%|██████▍   | 108/167 [00:49<00:30,  1.95it/s]15:12:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:17 - cmdstanpy - INFO - Chain [1] done processing
#  65%|██████▌   | 109/167 [00:50<00:29,  1.95it/s]15:12:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:17 - cmdstanpy - INFO - Chain [1] done processing
#  66%|██████▌   | 110/167 [00:50<00:29,  1.93it/s]15:12:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:18 - cmdstanpy - INFO - Chain [1] done processing
#  66%|██████▋   | 111/167 [00:51<00:28,  1.96it/s]15:12:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:18 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 112/167 [00:51<00:27,  1.98it/s]15:12:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:19 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 113/167 [00:52<00:27,  1.97it/s]15:12:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:19 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 114/167 [00:52<00:27,  1.92it/s]15:12:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:20 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 115/167 [00:53<00:26,  1.94it/s]15:12:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:20 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 116/167 [00:53<00:26,  1.92it/s]15:12:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:21 - cmdstanpy - INFO - Chain [1] done processing
#  70%|███████   | 117/167 [00:54<00:26,  1.92it/s]15:12:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:22 - cmdstanpy - INFO - Chain [1] done processing
#  71%|███████   | 118/167 [00:54<00:25,  1.91it/s]15:12:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:22 - cmdstanpy - INFO - Chain [1] done processing
#  71%|███████▏  | 119/167 [00:55<00:25,  1.91it/s]15:12:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:23 - cmdstanpy - INFO - Chain [1] done processing
#  72%|███████▏  | 120/167 [00:55<00:24,  1.88it/s]15:12:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:23 - cmdstanpy - INFO - Chain [1] done processing
#  72%|███████▏  | 121/167 [00:56<00:24,  1.84it/s]15:12:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:24 - cmdstanpy - INFO - Chain [1] done processing
#  73%|███████▎  | 122/167 [00:57<00:24,  1.85it/s]15:12:24 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:24 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 123/167 [00:57<00:23,  1.85it/s]15:12:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:25 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▍  | 124/167 [00:58<00:22,  1.88it/s]15:12:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:25 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▍  | 125/167 [00:58<00:22,  1.86it/s]15:12:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:26 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 126/167 [00:59<00:23,  1.77it/s]15:12:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:26 - cmdstanpy - INFO - Chain [1] done processing
#  76%|███████▌  | 127/167 [00:59<00:22,  1.79it/s]15:12:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:27 - cmdstanpy - INFO - Chain [1] done processing
#  77%|███████▋  | 128/167 [01:00<00:21,  1.82it/s]15:12:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:28 - cmdstanpy - INFO - Chain [1] done processing
#  77%|███████▋  | 129/167 [01:00<00:21,  1.80it/s]15:12:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:28 - cmdstanpy - INFO - Chain [1] done processing
#  78%|███████▊  | 130/167 [01:01<00:20,  1.79it/s]15:12:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:29 - cmdstanpy - INFO - Chain [1] done processing
#  78%|███████▊  | 131/167 [01:02<00:20,  1.72it/s]15:12:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:29 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 132/167 [01:02<00:20,  1.73it/s]15:12:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:30 - cmdstanpy - INFO - Chain [1] done processing
#  80%|███████▉  | 133/167 [01:03<00:19,  1.75it/s]15:12:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:30 - cmdstanpy - INFO - Chain [1] done processing
#  80%|████████  | 134/167 [01:03<00:18,  1.74it/s]15:12:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:31 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████  | 135/167 [01:04<00:18,  1.72it/s]15:12:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:32 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 136/167 [01:04<00:18,  1.70it/s]15:12:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:32 - cmdstanpy - INFO - Chain [1] done processing
#  82%|████████▏ | 137/167 [01:05<00:17,  1.69it/s]15:12:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:33 - cmdstanpy - INFO - Chain [1] done processing
#  83%|████████▎ | 138/167 [01:06<00:17,  1.69it/s]15:12:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:33 - cmdstanpy - INFO - Chain [1] done processing
#  83%|████████▎ | 139/167 [01:06<00:16,  1.70it/s]15:12:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:34 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 140/167 [01:07<00:15,  1.70it/s]15:12:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:35 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 141/167 [01:07<00:15,  1.70it/s]15:12:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:35 - cmdstanpy - INFO - Chain [1] done processing
#  85%|████████▌ | 142/167 [01:08<00:14,  1.70it/s]15:12:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:36 - cmdstanpy - INFO - Chain [1] done processing
#  86%|████████▌ | 143/167 [01:09<00:13,  1.73it/s]15:12:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:36 - cmdstanpy - INFO - Chain [1] done processing
#  86%|████████▌ | 144/167 [01:09<00:13,  1.74it/s]15:12:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:37 - cmdstanpy - INFO - Chain [1] done processing
#  87%|████████▋ | 145/167 [01:10<00:12,  1.72it/s]15:12:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:38 - cmdstanpy - INFO - Chain [1] done processing
#  87%|████████▋ | 146/167 [01:10<00:12,  1.68it/s]15:12:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:38 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 147/167 [01:11<00:12,  1.66it/s]15:12:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:39 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▊ | 148/167 [01:12<00:11,  1.65it/s]15:12:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:39 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 149/167 [01:12<00:10,  1.67it/s]15:12:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:40 - cmdstanpy - INFO - Chain [1] done processing
#  90%|████████▉ | 150/167 [01:13<00:10,  1.68it/s]15:12:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:41 - cmdstanpy - INFO - Chain [1] done processing
#  90%|█████████ | 151/167 [01:13<00:09,  1.68it/s]15:12:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:41 - cmdstanpy - INFO - Chain [1] done processing
#  91%|█████████ | 152/167 [01:14<00:08,  1.67it/s]15:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:42 - cmdstanpy - INFO - Chain [1] done processing
#  92%|█████████▏| 153/167 [01:15<00:08,  1.56it/s]15:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:42 - cmdstanpy - INFO - Chain [1] done processing
#  92%|█████████▏| 154/167 [01:15<00:08,  1.59it/s]15:12:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:43 - cmdstanpy - INFO - Chain [1] done processing
#  93%|█████████▎| 155/167 [01:16<00:07,  1.61it/s]15:12:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:44 - cmdstanpy - INFO - Chain [1] done processing
#  93%|█████████▎| 156/167 [01:17<00:06,  1.63it/s]15:12:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:44 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 157/167 [01:17<00:06,  1.66it/s]15:12:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:45 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 158/167 [01:18<00:05,  1.63it/s]15:12:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:46 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 159/167 [01:18<00:05,  1.56it/s]15:12:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:46 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 160/167 [01:19<00:04,  1.54it/s]15:12:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:47 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 161/167 [01:20<00:03,  1.56it/s]15:12:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:48 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 162/167 [01:20<00:03,  1.48it/s]15:12:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:48 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 163/167 [01:21<00:02,  1.50it/s]15:12:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:49 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 164/167 [01:22<00:01,  1.52it/s]15:12:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:50 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 165/167 [01:22<00:01,  1.51it/s]15:12:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:50 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 166/167 [01:23<00:00,  1.50it/s]15:12:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:51 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 167/167 [01:24<00:00,  1.98it/s]

# %%
# df_p = performance_metrics(df_cv)
# df_p
# Out:
#              horizon         mse       rmse        mae     mdape     smape  \
# 0    1 days 05:00:00  830.801908  28.823635  20.979693  0.214494  0.271116
# 1    1 days 06:00:00  781.161310  27.949263  20.332001  0.216285  0.275815
# 2    1 days 07:00:00  744.318407  27.282199  19.856921  0.220591  0.287958
# 3    1 days 08:00:00  693.999622  26.343873  19.496465  0.225308  0.296710
# 4    1 days 09:00:00  669.082453  25.866628  19.125994  0.223226  0.294526
# ..               ...         ...        ...        ...       ...       ...
# 255 11 days 20:00:00  866.325540  29.433409  21.712113  0.217519  0.277877
# 256 11 days 21:00:00  856.586191  29.267494  21.546989  0.216475  0.276861
# 257 11 days 22:00:00  837.743051  28.943791  21.270372  0.215517  0.274789
# 258 11 days 23:00:00  841.466875  29.008048  21.415609  0.215687  0.274497
# 259 12 days 00:00:00  847.462156  29.111203  21.446946  0.212420  0.270729
#
#      coverage
# 0    0.733230
# 1    0.747447
# 2    0.758669
# 3    0.765435
# 4    0.772016
# ..        ...
# 255  0.705212
# 256  0.710807
# 257  0.718108
# 258  0.712625
# 259  0.713854
#
# [260 rows x 7 columns]

# %% [markdown]
# # Lista de revisión

# %% [markdown]
# - [x]  Jupyter Notebook está abierto.
# - [ ]  El código no tiene errores
# - [ ]  Las celdas con el código han sido colocadas en el orden de ejecución.
# - [ ]  Los datos han sido descargados y preparados.
# - [ ]  Se ha realizado el paso 2: los datos han sido analizados
# - [ ]  Se entrenó el modelo y se seleccionaron los hiperparámetros
# - [ ]  Se han evaluado los modelos. Se expuso una conclusión
# - [ ]  La *RECM* para el conjunto de prueba no es más de 48
